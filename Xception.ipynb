# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from openslide import open_slide, __library_version__ as openslide_version
import os
from PIL import Image
from skimage.color import rgb2gray

import random
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix

from keras.layers import Dense, merge, GlobalAveragePooling2D
import keras
from keras.models import Model
from keras.applications.vgg16 import VGG16
# Out:
# Using TensorFlow backend.

# %%
def read_slide(slide, x, y, level, width, height, as_float=False):
    im = slide.read_region((x,y), level, (width, height))
    im = im.convert('RGB') # drop the alpha channel
    if as_float:
        im = np.asarray(im, dtype=np.float32)
    else:
        im = np.asarray(im)
    assert im.shape == (height, width, 3)
    return im

# %%
slide_test1 = open_slide('/home/wenshen2543/slide_data/tumor_110.tif')
tumor_mask_test1 = open_slide('/home/wenshen2543/slide_data/tumor_110_mask.tif')
slide_test_image1 = read_slide(slide_test1, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=slide_test1.level_dimensions[5][0], 
                         height=slide_test1.level_dimensions[5][1])
tumor_mask_test_image1 = read_slide(tumor_mask_test1, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=tumor_mask_test1.level_dimensions[5][0], 
                         height=tumor_mask_test1.level_dimensions[5][1])
tumor_mask_test_image1 = tumor_mask_test_image1[:,:,0]

# %%
plt.figure(figsize=(5,5), dpi=100)
plt.imshow(slide_test_image1)
plt.imshow(tumor_mask_test_image1, cmap='jet', alpha=0.5)

# %%
slide_test2 = open_slide('/home/wenshen2543/slide_data/tumor_078.tif')
tumor_mask_test2 = open_slide('/home/wenshen2543/slide_data/tumor_078_mask.tif')
slide_test_image2 = read_slide(slide_test2, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=slide_test2.level_dimensions[5][0], 
                         height=slide_test2.level_dimensions[5][1])
tumor_mask_test_image2 = read_slide(tumor_mask_test2, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=tumor_mask_test2.level_dimensions[5][0], 
                         height=tumor_mask_test2.level_dimensions[5][1])
tumor_mask_test_image2 = tumor_mask_test_image2[:,:,0]

# %%
plt.figure(figsize=(5,5), dpi=100)
plt.imshow(slide_test_image2)
plt.imshow(tumor_mask_test_image2, cmap='jet', alpha=0.5)

# %%
slide_test3 = open_slide('/home/wenshen2543/slide_data/tumor_005.tif')
tumor_mask_test3 = open_slide('/home/wenshen2543/slide_data/tumor_005_mask.tif')
slide_test_image3 = read_slide(slide_test3, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=slide_test3.level_dimensions[5][0], 
                         height=slide_test3.level_dimensions[5][1])
tumor_mask_test_image3 = read_slide(tumor_mask_test3, 
                         x=0, 
                         y=0, 
                         level=5, 
                         width=tumor_mask_test3.level_dimensions[5][0], 
                         height=tumor_mask_test3.level_dimensions[5][1])
tumor_mask_test_image3 = tumor_mask_test_image3[:,:,0]

# %%
plt.figure(figsize=(10,10), dpi=100)
plt.imshow(slide_test_image3)
plt.imshow(tumor_mask_test_image3, cmap='jet', alpha=0.5)

# %%
def find_tissue_pixels(image, intensity=0.8):
    im_gray = rgb2gray(image)
    assert im_gray.shape == (image.shape[0], image.shape[1])
    indices = np.where(im_gray <= intensity)
    return zip(indices[0], indices[1])


def apply_mask(im, mask, color=(255,0,0)):
    masked = np.copy(im)
    for x,y in mask: masked[x][y] = color
    return masked

# %%
def get_center_and_labels(slide_image_base, mask_image_base, downsample_factor, level):
    step = 60
    w = 60  
    labels = []
    
    width_bound = slide_image_base.level_dimensions[level][0]
    height_bound = slide_image_base.level_dimensions[level][1]
    
    center = []
  
    for j in range(0,height_bound,step):
        for i in range(0,width_bound,step):
            region = read_slide(mask_image_base, x= i * downsample_factor, y= j * downsample_factor, level= level, width=w, height=w)[:,:,0] 
            interest_region = read_slide(slide_image_base, x= i * downsample_factor, y= j * downsample_factor, level= level, width=w, height=w)
      
            tissue_pixels = find_tissue_pixels(interest_region)
            percent_tissue = len(list(tissue_pixels)) / float(interest_region.shape[0] * interest_region.shape[0])
            if percent_tissue > 0.1:
                center.append((int(i + w/2), int(j + w/2)))
                label = 1 if region.sum()>0 else 0
                labels.append(label)
    return center, labels

# %%
def get_center_and_labels_for_test(slide_image_base, mask_image_base, downsample_factor, level):
    step = 60
    w = 60  
    labels = []
  
    width_bound = slide_image_base.level_dimensions[level][0]
    height_bound = slide_image_base.level_dimensions[level][1]
  
    center = []
  
    for j in range(0,height_bound,step):
        for i in range(0,width_bound,step):
            region = read_slide(mask_image_base, x= i * downsample_factor, y= j * downsample_factor, level= level, width=w, height=w)[:,:,0] 
            interest_region = read_slide(slide_image_base, x= i * downsample_factor, y= j * downsample_factor, level= level, width=w, height=w)
      
            center.append((int(i + w/2), int(j + w/2)))
            
            label = 1 if region.sum()>0 else 0
            labels.append(label)
    return center, labels

# %%
def get_basepatches(center, slide_image_base, base_level, base_downsample_factor):
    w = 100
    base_patches = []
    
    for (i,j) in center:
        topleft_basei = int(i-w/2)
        topleft_basej = int(j-w/2)
    
   
        region_base = np.array(read_slide(slide_image_base, x= topleft_basei * base_downsample_factor, y= topleft_basej * base_downsample_factor, level= base_level, width=w, height=w))
    
    
        if topleft_basei < 0:
            region_base[:,0:(-topleft_basei),:] = 255
    
        if topleft_basei + w > slide_image_base.level_dimensions[base_level][0]:
            region_base[:,-(topleft_basei + w - slide_image_base.level_dimensions[base_level][0]):,:] =255
    
        if topleft_basej < 0:
            region_base[0:(-topleft_basej),:,:] = 255
     
        if topleft_basej + w > slide_image_base.level_dimensions[base_level][1]:
            region_base[-(topleft_basej + w - slide_image_base.level_dimensions[base_level][1]):,:,:] = 255
            
    
        base_patches.append(region_base)
    
    return base_patches

# %%
def get_patches(center, slide_image_base, base_level, downsample_factor, level):
    w = 100
    patches = []
  
    for (i,j) in center:
        new_i = i * 1.0 / slide_image_base.level_dimensions[base_level][0] * slide_image_base.level_dimensions[level][0]
        new_j = j * 1.0 / slide_image_base.level_dimensions[base_level][1] * slide_image_base.level_dimensions[level][1]
    
        topleft_i = int(new_i - w/2)
        topleft_j = int(new_j - w/2)
    
    
        region = np.array(read_slide(slide_image_base, x= topleft_i * downsample_factor, y= topleft_j * downsample_factor, level= level, width=w, height=w))
    
        if topleft_i < 0:
            region[:,0:(-topleft_i),:] = 255
    
        if topleft_i + w > slide_image_base.level_dimensions[level][0]:
            region[:,-(topleft_i + w - slide_image_base.level_dimensions[level][0]):,:] = 255
    
        if topleft_j < 0:
            region[0:(-topleft_j),:,:] = 255
     
        if topleft_j + w > slide_image_base.level_dimensions[level][1]:
            region[-(topleft_j + w - slide_image_base.level_dimensions[level][1]):,:,:] = 255
        
        patches.append(region)
    return patches

# %%
x_train1 = []
x_train2 = []

y_train = []

for i in ["091","084","101","001","016","019","023","031","057","064","081","075","096"]:
    slide_path = "/home/wenshen2543/slide_data/" + "tumor_"+ i + ".tif"
    tumor_mask_path = "/home/wenshen2543/slide_data/" + "tumor_"+ i + "_mask.tif"

    slide = open_slide(slide_path)
    tumor_mask = open_slide(tumor_mask_path)
  
    center,labels = get_center_and_labels(slide_image_base=slide, mask_image_base=tumor_mask, downsample_factor=8, level=3)
    
    base_patches = get_basepatches(center, slide_image_base=slide, base_level=3, base_downsample_factor=8)
    print("=> base_patches for Slide", i, "done successfully!")
    patches1 = get_patches(center, slide_image_base=slide, base_level=3, downsample_factor=16, level=4)
    print("=> patches1 for Slide", i, "done successfully!")
  
    x_train1 += base_patches
  
    x_train2 += patches1
  
    y_train += labels
  
    print("Get patches on Slide", i, "successfully!")
# Out:
# => base_patches for Slide 091 done successfully!
# => patches1 for Slide 091 done successfully!
# Get patches on Slide 091 successfully!
# => base_patches for Slide 084 done successfully!
# => patches1 for Slide 084 done successfully!
# Get patches on Slide 084 successfully!
# => base_patches for Slide 101 done successfully!
# => patches1 for Slide 101 done successfully!
# Get patches on Slide 101 successfully!
# => base_patches for Slide 001 done successfully!
# => patches1 for Slide 001 done successfully!
# Get patches on Slide 001 successfully!
# => base_patches for Slide 016 done successfully!
# => patches1 for Slide 016 done successfully!
# Get patches on Slide 016 successfully!
# => base_patches for Slide 019 done successfully!
# => patches1 for Slide 019 done successfully!
# Get patches on Slide 019 successfully!
# => base_patches for Slide 023 done successfully!
# => patches1 for Slide 023 done successfully!
# Get patches on Slide 023 successfully!
# => base_patches for Slide 031 done successfully!
# => patches1 for Slide 031 done successfully!
# Get patches on Slide 031 successfully!
# => base_patches for Slide 057 done successfully!
# => patches1 for Slide 057 done successfully!
# Get patches on Slide 057 successfully!
# => base_patches for Slide 064 done successfully!
# => patches1 for Slide 064 done successfully!
# Get patches on Slide 064 successfully!
# => base_patches for Slide 081 done successfully!
# => patches1 for Slide 081 done successfully!
# Get patches on Slide 081 successfully!
# => base_patches for Slide 075 done successfully!
# => patches1 for Slide 075 done successfully!
# Get patches on Slide 075 successfully!
# => base_patches for Slide 096 done successfully!
# => patches1 for Slide 096 done successfully!
# Get patches on Slide 096 successfully!

# %%
x_test1 = []
x_test2 = []
y_test = []

for i in ["078","110","005"]:
    slide_path = "/home/wenshen2543/slide_data/"+"tumor_"+ i + ".tif"
    tumor_mask_path = "/home/wenshen2543/slide_data/"+"tumor_"+ i + "_mask.tif"

    slide = open_slide(slide_path)
    tumor_mask = open_slide(tumor_mask_path)
  
    center,labels = get_center_and_labels_for_test(slide_image_base=slide, mask_image_base=tumor_mask, downsample_factor=8, level=3)
    base_patches = get_basepatches(center, slide_image_base=slide, base_level=3, base_downsample_factor=8)
    print("=> base_patches for Slide", i, "done successfully!")
    patches1 = get_patches(center, slide_image_base=slide, base_level=3, downsample_factor=16, level=4)
    print("=> patches1 for Slide", i, "done successfully!")
  
    x_test1 += base_patches
    x_test2 += patches1
  
    y_test += labels
  
    print("Get patches on Slide", i, "successfully!")
# Out:
# => base_patches for Slide 078 done successfully!
# => patches1 for Slide 078 done successfully!
# Get patches on Slide 078 successfully!
# => base_patches for Slide 110 done successfully!
# => patches1 for Slide 110 done successfully!
# Get patches on Slide 110 successfully!
# => base_patches for Slide 005 done successfully!
# => patches1 for Slide 005 done successfully!
# Get patches on Slide 005 successfully!

# %%
import random
def oversampling(x_train1, x_train2, y_train):
    sample_num = int(len(y_train) - sum(y_train))
    
    indices = [i for i, x in enumerate(y_train) if x == 1]
    more = [i for i, x in enumerate(y_train) if x == 0]
    
    oversample = [random.choice(indices) for _ in range(sample_num)]
    
    X1 = []
    X2 = []
    y = []
    for i in oversample:
        X1.append(x_train1[i])
        X2.append(x_train2[i])
        y.append(y_train[i])
    for i in more:
        X1.append(x_train1[i])
        X2.append(x_train2[i])
        y.append(y_train[i])
    
    X1, X2, y = shuffle(X1, X2, y, random_state=42)
    print('The final label 1 (tumor) percent to check if dataset is balance: {}%'.format(sum(y)*1.0*100/len(y)))
  
    return X1, X2, y

# %%
def undersampling(x_train1, x_train2, y_train):
    sample_num = int(sum(y_train))
    
    indices = [i for i, x in enumerate(y_train) if x == 0]
    more = [i for i, x in enumerate(y_train) if x == 1]
    
    oversample = [random.choice(indices) for _ in range(sample_num)]
    
    X1 = []
    X2 = []
    y = []
    for i in oversample:
        X1.append(x_train1[i])
        X2.append(x_train2[i])
        y.append(y_train[i])
    for i in more:
        X1.append(x_train1[i])
        X2.append(x_train2[i])
        y.append(y_train[i])
    
    X1, X2, y = shuffle(X1, X2, y, random_state=42)
    print('The final label 1 (tumor) percent to check if dataset is balance: {}%'.format(sum(y)*1.0*100/len(y)))
  
    return X1, X2, y

# %%
X_train1_over, X_train2_over, y_train_over = oversampling(x_train1, x_train2, y_train)
print(len(X_train1_over),len(X_train2_over),len(y_train_over))
# Out:
# The final label 1 (tumor) percent to check if dataset is balance: 50.0%
# 222134 222134 222134

# %%
from keras.applications.xception import Xception
def My_FusionModel3(X_train1, X_train2, y_train, X_test1, X_test2, y_test):
    model1 = Xception(include_top=False, weights='imagenet',input_shape=(100, 100, 3))
    for layer in model1.layers:
        layer.trainable = False
    
    inp = model1.input
    out = model1.output

    model2 = Xception(include_top=False, weights='imagenet',input_shape=(100, 100, 3))
    for layer in model2.layers:
        layer.name = layer.name + str("_2")
        layer.trainable = False

    inp2 = model2.input
    out2 = model2.output

    merged = merge([out, out2],mode='concat')
  
    merged = GlobalAveragePooling2D()(merged)

    merged = Dense(1024, activation='relu')(merged)
    merged = Dense(1, activation='sigmoid')(merged)

    model_fusion = Model([inp, inp2], merged)
  
    model_fusion.compile(loss='binary_crossentropy',
              optimizer=tf.train.AdamOptimizer(),
              metrics=['acc'])
  
    model_fusion.summary()
    
    from sklearn.model_selection import train_test_split
    X_train1_shuffle, X_val1_shuffle, X_train2_shuffle, X_val2_shuffle, Y_train_shuffle, Y_val_shuffle = train_test_split(X_train1, X_train2, y_train, test_size=0.1, random_state=42, shuffle=True)
  
    history4 = model_fusion.fit([X_train1_shuffle, X_train2_shuffle], Y_train_shuffle, validation_data=([X_val1_shuffle, X_val2_shuffle],Y_val_shuffle),nb_epoch=10, batch_size=32)
  
    scores = model_fusion.evaluate([X_test1, X_test2], y_test)
  
    y_predict = model_fusion.predict([X_test1, X_test2])
    y_predict_prob = y_predict
  
    y_predict_label = np.array([0]*len(y_test))
    y_predict_label[(np.where(y_predict_prob>=0.5)[0])] = 1

  
    print(y_predict_label.shape)
    print('Loss (Two-scale Model):', scores[0])
    print('Accuracy (Two-scale Model):', scores[1])
    print('Precision (Two-scale Model):', precision_score(y_test,y_predict_label))
    print('Recall (Two-scale Model):', recall_score(y_test,y_predict_label))
    print('F1 (Two-scale Model):', f1_score(y_test,y_predict_label))
    print('ROCAUC (Two-scale Model):', roc_auc_score(y_test,y_predict_label))
    print('Confusion Matrix (Two-scale Model):\n', confusion_matrix(y_test,y_predict_label))
  
    return model_fusion, y_predict_label, y_predict_prob, history4

# %%
model_Xcep, y_predict_label_Xcep, y_predict_prob_X_cep, history4 = My_FusionModel3(np.asarray(X_train1_over), np.asarray(X_train2_over), np.asarray(y_train_over),np.asarray(x_test1),np.asarray(x_test2),np.asarray(y_test))
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 100, 100, 3)   0
# ____________________________________________________________________________________________________
# input_2_2 (InputLayer)           (None, 100, 100, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, 49, 49, 32)    864         input_1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_2 (Convolution2D)   (None, 49, 49, 32)    864         input_2_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn (BatchNormalizat (None, 49, 49, 32)    128         block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_bn_2 (BatchNormaliz (None, 49, 49, 32)    128         block1_conv1_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act (Activation)    (None, 49, 49, 32)    0           block1_conv1_bn[0][0]
# ____________________________________________________________________________________________________
# block1_conv1_act_2 (Activation)  (None, 49, 49, 32)    0           block1_conv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, 47, 47, 64)    18432       block1_conv1_act[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_2 (Convolution2D)   (None, 47, 47, 64)    18432       block1_conv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_bn (BatchNormalizat (None, 47, 47, 64)    256         block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_bn_2 (BatchNormaliz (None, 47, 47, 64)    256         block1_conv2_2[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_act (Activation)    (None, 47, 47, 64)    0           block1_conv2_bn[0][0]
# ____________________________________________________________________________________________________
# block1_conv2_act_2 (Activation)  (None, 47, 47, 64)    0           block1_conv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1 (SeparableConvol (None, 47, 47, 128)   8768        block1_conv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1_2 (SeparableConv (None, 47, 47, 128)   8768        block1_conv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1_bn (BatchNormali (None, 47, 47, 128)   512         block2_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv1_bn_2 (BatchNorma (None, 47, 47, 128)   512         block2_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_act (Activation) (None, 47, 47, 128)   0           block2_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_act_2 (Activatio (None, 47, 47, 128)   0           block2_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2 (SeparableConvol (None, 47, 47, 128)   17536       block2_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_2 (SeparableConv (None, 47, 47, 128)   17536       block2_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_bn (BatchNormali (None, 47, 47, 128)   512         block2_sepconv2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 24, 24, 128)   8192        block1_conv2_act[0][0]
# ____________________________________________________________________________________________________
# block2_sepconv2_bn_2 (BatchNorma (None, 47, 47, 128)   512         block2_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_5_2 (Convolution2D (None, 24, 24, 128)   8192        block1_conv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 24, 24, 128)   0           block2_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 24, 24, 128)   512         convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# block2_pool_2 (MaxPooling2D)     (None, 24, 24, 128)   0           block2_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_5_2 (BatchNor (None, 24, 24, 128)   512         convolution2d_5_2[0][0]
# ____________________________________________________________________________________________________
# merge_1 (Merge)                  (None, 24, 24, 128)   0           block2_pool[0][0]
#                                                                    batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# merge_13_2 (Merge)               (None, 24, 24, 128)   0           block2_pool_2[0][0]
#                                                                    batchnormalization_5_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_act (Activation) (None, 24, 24, 128)   0           merge_1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_act_2 (Activatio (None, 24, 24, 128)   0           merge_13_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1 (SeparableConvol (None, 24, 24, 256)   33920       block3_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_2 (SeparableConv (None, 24, 24, 256)   33920       block3_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_bn (BatchNormali (None, 24, 24, 256)   1024        block3_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv1_bn_2 (BatchNorma (None, 24, 24, 256)   1024        block3_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_act (Activation) (None, 24, 24, 256)   0           block3_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_act_2 (Activatio (None, 24, 24, 256)   0           block3_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2 (SeparableConvol (None, 24, 24, 256)   67840       block3_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_2 (SeparableConv (None, 24, 24, 256)   67840       block3_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_bn (BatchNormali (None, 24, 24, 256)   1024        block3_sepconv2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 12, 12, 256)   32768       merge_1[0][0]
# ____________________________________________________________________________________________________
# block3_sepconv2_bn_2 (BatchNorma (None, 24, 24, 256)   1024        block3_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_6_2 (Convolution2D (None, 12, 12, 256)   32768       merge_13_2[0][0]
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 12, 12, 256)   0           block3_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_2 (BatchNorma (None, 12, 12, 256)   1024        convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# block3_pool_2 (MaxPooling2D)     (None, 12, 12, 256)   0           block3_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_6_2 (BatchNor (None, 12, 12, 256)   1024        convolution2d_6_2[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 12, 12, 256)   0           block3_pool[0][0]
#                                                                    batchnormalization_2[0][0]
# ____________________________________________________________________________________________________
# merge_14_2 (Merge)               (None, 12, 12, 256)   0           block3_pool_2[0][0]
#                                                                    batchnormalization_6_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_act (Activation) (None, 12, 12, 256)   0           merge_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_act_2 (Activatio (None, 12, 12, 256)   0           merge_14_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1 (SeparableConvol (None, 12, 12, 728)   188672      block4_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_2 (SeparableConv (None, 12, 12, 728)   188672      block4_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_bn (BatchNormali (None, 12, 12, 728)   2912        block4_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv1_bn_2 (BatchNorma (None, 12, 12, 728)   2912        block4_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_act (Activation) (None, 12, 12, 728)   0           block4_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_act_2 (Activatio (None, 12, 12, 728)   0           block4_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2 (SeparableConvol (None, 12, 12, 728)   536536      block4_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_2 (SeparableConv (None, 12, 12, 728)   536536      block4_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_bn (BatchNormali (None, 12, 12, 728)   2912        block4_sepconv2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 6, 6, 728)     186368      merge_2[0][0]
# ____________________________________________________________________________________________________
# block4_sepconv2_bn_2 (BatchNorma (None, 12, 12, 728)   2912        block4_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_7_2 (Convolution2D (None, 6, 6, 728)     186368      merge_14_2[0][0]
# ____________________________________________________________________________________________________
# block4_pool (MaxPooling2D)       (None, 6, 6, 728)     0           block4_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_3 (BatchNorma (None, 6, 6, 728)     2912        convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# block4_pool_2 (MaxPooling2D)     (None, 6, 6, 728)     0           block4_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_7_2 (BatchNor (None, 6, 6, 728)     2912        convolution2d_7_2[0][0]
# ____________________________________________________________________________________________________
# merge_3 (Merge)                  (None, 6, 6, 728)     0           block4_pool[0][0]
#                                                                    batchnormalization_3[0][0]
# ____________________________________________________________________________________________________
# merge_15_2 (Merge)               (None, 6, 6, 728)     0           block4_pool_2[0][0]
#                                                                    batchnormalization_7_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_act (Activation) (None, 6, 6, 728)     0           merge_3[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_act_2 (Activatio (None, 6, 6, 728)     0           merge_15_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1 (SeparableConvol (None, 6, 6, 728)     536536      block5_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_2 (SeparableConv (None, 6, 6, 728)     536536      block5_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_bn (BatchNormali (None, 6, 6, 728)     2912        block5_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv1_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block5_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_act (Activation) (None, 6, 6, 728)     0           block5_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_act_2 (Activatio (None, 6, 6, 728)     0           block5_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2 (SeparableConvol (None, 6, 6, 728)     536536      block5_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_2 (SeparableConv (None, 6, 6, 728)     536536      block5_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_bn (BatchNormali (None, 6, 6, 728)     2912        block5_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv2_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block5_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_act (Activation) (None, 6, 6, 728)     0           block5_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_act_2 (Activatio (None, 6, 6, 728)     0           block5_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3 (SeparableConvol (None, 6, 6, 728)     536536      block5_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_2 (SeparableConv (None, 6, 6, 728)     536536      block5_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_bn (BatchNormali (None, 6, 6, 728)     2912        block5_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block5_sepconv3_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block5_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_4 (Merge)                  (None, 6, 6, 728)     0           block5_sepconv3_bn[0][0]
#                                                                    merge_3[0][0]
# ____________________________________________________________________________________________________
# merge_16_2 (Merge)               (None, 6, 6, 728)     0           block5_sepconv3_bn_2[0][0]
#                                                                    merge_15_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_act (Activation) (None, 6, 6, 728)     0           merge_4[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_act_2 (Activatio (None, 6, 6, 728)     0           merge_16_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1 (SeparableConvol (None, 6, 6, 728)     536536      block6_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_2 (SeparableConv (None, 6, 6, 728)     536536      block6_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_bn (BatchNormali (None, 6, 6, 728)     2912        block6_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv1_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block6_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_act (Activation) (None, 6, 6, 728)     0           block6_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_act_2 (Activatio (None, 6, 6, 728)     0           block6_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2 (SeparableConvol (None, 6, 6, 728)     536536      block6_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_2 (SeparableConv (None, 6, 6, 728)     536536      block6_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_bn (BatchNormali (None, 6, 6, 728)     2912        block6_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv2_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block6_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_act (Activation) (None, 6, 6, 728)     0           block6_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_act_2 (Activatio (None, 6, 6, 728)     0           block6_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3 (SeparableConvol (None, 6, 6, 728)     536536      block6_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_2 (SeparableConv (None, 6, 6, 728)     536536      block6_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_bn (BatchNormali (None, 6, 6, 728)     2912        block6_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block6_sepconv3_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block6_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_5 (Merge)                  (None, 6, 6, 728)     0           block6_sepconv3_bn[0][0]
#                                                                    merge_4[0][0]
# ____________________________________________________________________________________________________
# merge_17_2 (Merge)               (None, 6, 6, 728)     0           block6_sepconv3_bn_2[0][0]
#                                                                    merge_16_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_act (Activation) (None, 6, 6, 728)     0           merge_5[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_act_2 (Activatio (None, 6, 6, 728)     0           merge_17_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1 (SeparableConvol (None, 6, 6, 728)     536536      block7_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_2 (SeparableConv (None, 6, 6, 728)     536536      block7_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_bn (BatchNormali (None, 6, 6, 728)     2912        block7_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv1_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block7_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_act (Activation) (None, 6, 6, 728)     0           block7_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_act_2 (Activatio (None, 6, 6, 728)     0           block7_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2 (SeparableConvol (None, 6, 6, 728)     536536      block7_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_2 (SeparableConv (None, 6, 6, 728)     536536      block7_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_bn (BatchNormali (None, 6, 6, 728)     2912        block7_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv2_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block7_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_act (Activation) (None, 6, 6, 728)     0           block7_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_act_2 (Activatio (None, 6, 6, 728)     0           block7_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3 (SeparableConvol (None, 6, 6, 728)     536536      block7_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_2 (SeparableConv (None, 6, 6, 728)     536536      block7_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_bn (BatchNormali (None, 6, 6, 728)     2912        block7_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block7_sepconv3_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block7_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_6 (Merge)                  (None, 6, 6, 728)     0           block7_sepconv3_bn[0][0]
#                                                                    merge_5[0][0]
# ____________________________________________________________________________________________________
# merge_18_2 (Merge)               (None, 6, 6, 728)     0           block7_sepconv3_bn_2[0][0]
#                                                                    merge_17_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_act (Activation) (None, 6, 6, 728)     0           merge_6[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_act_2 (Activatio (None, 6, 6, 728)     0           merge_18_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1 (SeparableConvol (None, 6, 6, 728)     536536      block8_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_2 (SeparableConv (None, 6, 6, 728)     536536      block8_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_bn (BatchNormali (None, 6, 6, 728)     2912        block8_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv1_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block8_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_act (Activation) (None, 6, 6, 728)     0           block8_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_act_2 (Activatio (None, 6, 6, 728)     0           block8_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2 (SeparableConvol (None, 6, 6, 728)     536536      block8_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_2 (SeparableConv (None, 6, 6, 728)     536536      block8_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_bn (BatchNormali (None, 6, 6, 728)     2912        block8_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv2_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block8_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_act (Activation) (None, 6, 6, 728)     0           block8_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_act_2 (Activatio (None, 6, 6, 728)     0           block8_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3 (SeparableConvol (None, 6, 6, 728)     536536      block8_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_2 (SeparableConv (None, 6, 6, 728)     536536      block8_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_bn (BatchNormali (None, 6, 6, 728)     2912        block8_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block8_sepconv3_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block8_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, 6, 6, 728)     0           block8_sepconv3_bn[0][0]
#                                                                    merge_6[0][0]
# ____________________________________________________________________________________________________
# merge_19_2 (Merge)               (None, 6, 6, 728)     0           block8_sepconv3_bn_2[0][0]
#                                                                    merge_18_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_act (Activation) (None, 6, 6, 728)     0           merge_7[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_act_2 (Activatio (None, 6, 6, 728)     0           merge_19_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1 (SeparableConvol (None, 6, 6, 728)     536536      block9_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_2 (SeparableConv (None, 6, 6, 728)     536536      block9_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_bn (BatchNormali (None, 6, 6, 728)     2912        block9_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv1_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block9_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_act (Activation) (None, 6, 6, 728)     0           block9_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_act_2 (Activatio (None, 6, 6, 728)     0           block9_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2 (SeparableConvol (None, 6, 6, 728)     536536      block9_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_2 (SeparableConv (None, 6, 6, 728)     536536      block9_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_bn (BatchNormali (None, 6, 6, 728)     2912        block9_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv2_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block9_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_act (Activation) (None, 6, 6, 728)     0           block9_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_act_2 (Activatio (None, 6, 6, 728)     0           block9_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3 (SeparableConvol (None, 6, 6, 728)     536536      block9_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_2 (SeparableConv (None, 6, 6, 728)     536536      block9_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_bn (BatchNormali (None, 6, 6, 728)     2912        block9_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block9_sepconv3_bn_2 (BatchNorma (None, 6, 6, 728)     2912        block9_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                  (None, 6, 6, 728)     0           block9_sepconv3_bn[0][0]
#                                                                    merge_7[0][0]
# ____________________________________________________________________________________________________
# merge_20_2 (Merge)               (None, 6, 6, 728)     0           block9_sepconv3_bn_2[0][0]
#                                                                    merge_19_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_act (Activation (None, 6, 6, 728)     0           merge_8[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_act_2 (Activati (None, 6, 6, 728)     0           merge_20_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1 (SeparableConvo (None, 6, 6, 728)     536536      block10_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_2 (SeparableCon (None, 6, 6, 728)     536536      block10_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_bn (BatchNormal (None, 6, 6, 728)     2912        block10_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv1_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block10_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_act (Activation (None, 6, 6, 728)     0           block10_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_act_2 (Activati (None, 6, 6, 728)     0           block10_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2 (SeparableConvo (None, 6, 6, 728)     536536      block10_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_2 (SeparableCon (None, 6, 6, 728)     536536      block10_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_bn (BatchNormal (None, 6, 6, 728)     2912        block10_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv2_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block10_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_act (Activation (None, 6, 6, 728)     0           block10_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_act_2 (Activati (None, 6, 6, 728)     0           block10_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3 (SeparableConvo (None, 6, 6, 728)     536536      block10_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_2 (SeparableCon (None, 6, 6, 728)     536536      block10_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_bn (BatchNormal (None, 6, 6, 728)     2912        block10_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block10_sepconv3_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block10_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                  (None, 6, 6, 728)     0           block10_sepconv3_bn[0][0]
#                                                                    merge_8[0][0]
# ____________________________________________________________________________________________________
# merge_21_2 (Merge)               (None, 6, 6, 728)     0           block10_sepconv3_bn_2[0][0]
#                                                                    merge_20_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_act (Activation (None, 6, 6, 728)     0           merge_9[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_act_2 (Activati (None, 6, 6, 728)     0           merge_21_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1 (SeparableConvo (None, 6, 6, 728)     536536      block11_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_2 (SeparableCon (None, 6, 6, 728)     536536      block11_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_bn (BatchNormal (None, 6, 6, 728)     2912        block11_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv1_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block11_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_act (Activation (None, 6, 6, 728)     0           block11_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_act_2 (Activati (None, 6, 6, 728)     0           block11_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2 (SeparableConvo (None, 6, 6, 728)     536536      block11_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_2 (SeparableCon (None, 6, 6, 728)     536536      block11_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_bn (BatchNormal (None, 6, 6, 728)     2912        block11_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv2_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block11_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_act (Activation (None, 6, 6, 728)     0           block11_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_act_2 (Activati (None, 6, 6, 728)     0           block11_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3 (SeparableConvo (None, 6, 6, 728)     536536      block11_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_2 (SeparableCon (None, 6, 6, 728)     536536      block11_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_bn (BatchNormal (None, 6, 6, 728)     2912        block11_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block11_sepconv3_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block11_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                 (None, 6, 6, 728)     0           block11_sepconv3_bn[0][0]
#                                                                    merge_9[0][0]
# ____________________________________________________________________________________________________
# merge_22_2 (Merge)               (None, 6, 6, 728)     0           block11_sepconv3_bn_2[0][0]
#                                                                    merge_21_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_act (Activation (None, 6, 6, 728)     0           merge_10[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_act_2 (Activati (None, 6, 6, 728)     0           merge_22_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1 (SeparableConvo (None, 6, 6, 728)     536536      block12_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_2 (SeparableCon (None, 6, 6, 728)     536536      block12_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_bn (BatchNormal (None, 6, 6, 728)     2912        block12_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv1_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block12_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_act (Activation (None, 6, 6, 728)     0           block12_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_act_2 (Activati (None, 6, 6, 728)     0           block12_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2 (SeparableConvo (None, 6, 6, 728)     536536      block12_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_2 (SeparableCon (None, 6, 6, 728)     536536      block12_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_bn (BatchNormal (None, 6, 6, 728)     2912        block12_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv2_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block12_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_act (Activation (None, 6, 6, 728)     0           block12_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_act_2 (Activati (None, 6, 6, 728)     0           block12_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3 (SeparableConvo (None, 6, 6, 728)     536536      block12_sepconv3_act[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_2 (SeparableCon (None, 6, 6, 728)     536536      block12_sepconv3_act_2[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_bn (BatchNormal (None, 6, 6, 728)     2912        block12_sepconv3[0][0]
# ____________________________________________________________________________________________________
# block12_sepconv3_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block12_sepconv3_2[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                 (None, 6, 6, 728)     0           block12_sepconv3_bn[0][0]
#                                                                    merge_10[0][0]
# ____________________________________________________________________________________________________
# merge_23_2 (Merge)               (None, 6, 6, 728)     0           block12_sepconv3_bn_2[0][0]
#                                                                    merge_22_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_act (Activation (None, 6, 6, 728)     0           merge_11[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_act_2 (Activati (None, 6, 6, 728)     0           merge_23_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1 (SeparableConvo (None, 6, 6, 728)     536536      block13_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_2 (SeparableCon (None, 6, 6, 728)     536536      block13_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_bn (BatchNormal (None, 6, 6, 728)     2912        block13_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv1_bn_2 (BatchNorm (None, 6, 6, 728)     2912        block13_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_act (Activation (None, 6, 6, 728)     0           block13_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_act_2 (Activati (None, 6, 6, 728)     0           block13_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2 (SeparableConvo (None, 6, 6, 1024)    752024      block13_sepconv2_act[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_2 (SeparableCon (None, 6, 6, 1024)    752024      block13_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_bn (BatchNormal (None, 6, 6, 1024)    4096        block13_sepconv2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 3, 3, 1024)    745472      merge_11[0][0]
# ____________________________________________________________________________________________________
# block13_sepconv2_bn_2 (BatchNorm (None, 6, 6, 1024)    4096        block13_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_8_2 (Convolution2D (None, 3, 3, 1024)    745472      merge_23_2[0][0]
# ____________________________________________________________________________________________________
# block13_pool (MaxPooling2D)      (None, 3, 3, 1024)    0           block13_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_4 (BatchNorma (None, 3, 3, 1024)    4096        convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# block13_pool_2 (MaxPooling2D)    (None, 3, 3, 1024)    0           block13_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_8_2 (BatchNor (None, 3, 3, 1024)    4096        convolution2d_8_2[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                 (None, 3, 3, 1024)    0           block13_pool[0][0]
#                                                                    batchnormalization_4[0][0]
# ____________________________________________________________________________________________________
# merge_24_2 (Merge)               (None, 3, 3, 1024)    0           block13_pool_2[0][0]
#                                                                    batchnormalization_8_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1 (SeparableConvo (None, 3, 3, 1536)    1582080     merge_12[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_2 (SeparableCon (None, 3, 3, 1536)    1582080     merge_24_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_bn (BatchNormal (None, 3, 3, 1536)    6144        block14_sepconv1[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_bn_2 (BatchNorm (None, 3, 3, 1536)    6144        block14_sepconv1_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_act (Activation (None, 3, 3, 1536)    0           block14_sepconv1_bn[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv1_act_2 (Activati (None, 3, 3, 1536)    0           block14_sepconv1_bn_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2 (SeparableConvo (None, 3, 3, 2048)    3159552     block14_sepconv1_act[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_2 (SeparableCon (None, 3, 3, 2048)    3159552     block14_sepconv1_act_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_bn (BatchNormal (None, 3, 3, 2048)    8192        block14_sepconv2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_bn_2 (BatchNorm (None, 3, 3, 2048)    8192        block14_sepconv2_2[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_act (Activation (None, 3, 3, 2048)    0           block14_sepconv2_bn[0][0]
# ____________________________________________________________________________________________________
# block14_sepconv2_act_2 (Activati (None, 3, 3, 2048)    0           block14_sepconv2_bn_2[0][0]
# ____________________________________________________________________________________________________
# merge_25 (Merge)                 (None, 3, 3, 4096)    0           block14_sepconv2_act[0][0]
#                                                                    block14_sepconv2_act_2[0][0]
# ____________________________________________________________________________________________________
# globalaveragepooling2d_1 (Global (None, 4096)          0           merge_25[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1024)          4195328     globalaveragepooling2d_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1)             1025        dense_1[0][0]
# ====================================================================================================
# Total params: 45,919,313
# Trainable params: 4,196,353
# Non-trainable params: 41,722,960
# ____________________________________________________________________________________________________
# Train on 199920 samples, validate on 22214 samples
# Epoch 1/10
# 199920/199920 [==============================] - 1344s - loss: 0.2086 - acc: 0.9164 - val_loss: 0.0801 - val_acc: 0.9723
# Epoch 2/10
# 199920/199920 [==============================] - 1332s - loss: 0.1104 - acc: 0.9590 - val_loss: 0.0721 - val_acc: 0.9748
# Epoch 3/10
# 199920/199920 [==============================] - 1334s - loss: 0.0813 - acc: 0.9709 - val_loss: 0.0443 - val_acc: 0.9871
# Epoch 4/10
# 199920/199920 [==============================] - 1334s - loss: 0.0653 - acc: 0.9772 - val_loss: 0.0306 - val_acc: 0.9905
# Epoch 5/10
# 199920/199920 [==============================] - 1333s - loss: 0.0559 - acc: 0.9805 - val_loss: 0.0212 - val_acc: 0.9934
# Epoch 6/10
# 199920/199920 [==============================] - 1334s - loss: 0.0506 - acc: 0.9825 - val_loss: 0.0480 - val_acc: 0.9874
# Epoch 7/10
# 199920/199920 [==============================] - 1334s - loss: 0.0447 - acc: 0.9851 - val_loss: 0.0283 - val_acc: 0.9928
# Epoch 8/10
# 199920/199920 [==============================] - 1335s - loss: 0.0431 - acc: 0.9858 - val_loss: 0.0297 - val_acc: 0.9922
# Epoch 9/10
# 199920/199920 [==============================] - 1335s - loss: 0.0413 - acc: 0.9865 - val_loss: 0.0229 - val_acc: 0.9946
# Epoch 10/10
# 199920/199920 [==============================] - 1335s - loss: 0.0378 - acc: 0.9879 - val_loss: 0.0355 - val_acc: 0.9919
# 168686/168686 [==============================] - 966s
# (168686,)
# Loss (Two-scale Model): 0.17694432004529564
# Accuracy (Two-scale Model): 0.9701812835682866
# Precision (Two-scale Model): 0.8700504916290194
# Recall (Two-scale Model): 0.6177358490566037
# F1 (Two-scale Model): 0.722498069072051
# ROCAUC (Two-scale Model): 0.8057746714888171
# Confusion Matrix (Two-scale Model):
#  [[157108    978]
#  [  4052   6548]]

# %%
acc = history4.history['acc']
val_acc = history4.history['val_acc']
loss = history4.history['loss']
val_loss = history4.history['val_loss']

# Get the number of epochs
epochs = range(1,len(acc)+1)

plt.title('Training and validation accuracy')
plt.grid()
plt.plot(epochs, acc, color='blue', label='Train')
plt.plot(epochs, val_acc, color='orange', label='Val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

_ = plt.figure()
plt.title('Training and validation loss')
plt.grid()
plt.plot(epochs, loss, color='blue', label='Train')
plt.plot(epochs, val_loss, color='orange', label='Val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# %%
#from PIL import Image
from PIL import Image
# 110 slide
test1 = Image.fromarray(slide_test_image1.astype('uint8'), 'RGB')
test1 = test1.resize((197,150), Image.ANTIALIAS)

# 078 slide
test2 = Image.fromarray(slide_test_image2.astype('uint8'), 'RGB')
test2 = test2.resize((197,232), Image.ANTIALIAS)

# 005 slide
test3 = Image.fromarray(slide_test_image3.astype('uint8'), 'RGB')
test3 = test3.resize((204,458), Image.ANTIALIAS)

# %%
# Ground Truth of 078 slide
plt.figure(figsize=(21,21), dpi=100)
plt.subplot(1,3,1)
plt.title("Ground Truth of 078 slide")
plt.imshow(slide_test_image2)
plt.imshow(tumor_mask_test_image2, cmap='jet', alpha=0.5)

# prediction of probability heatmap of 078 slide
plt.subplot(1,3,2)
plt.title("prediction heatmap of 078 slide (prob)")
prob_image2 = np.reshape(y_predict_prob_X_cep[0:45704],(-1,197))
plt.imshow(test2)
plt.imshow(prob_image2 , cmap='jet',alpha=0.5)

# prediction of label heatmap of 078 slide
plt.subplot(1,3,3)
plt.title("prediction heatmap of 078 slide (label)")
label_image2 = np.reshape(y_predict_label_Xcep[0:45704],(-1,197))
plt.imshow(test2)
plt.imshow(label_image2 , cmap='jet',alpha=0.5)

# %%
# Ground Truth of 110 slide
plt.figure(figsize=(21,21), dpi=100)
plt.subplot(1,3,1)
plt.title("Ground Truth of 110 slide")
plt.imshow(slide_test_image1)
plt.imshow(tumor_mask_test_image1, cmap='jet', alpha=0.5)

# prediction of probability heatmap of 110 slide
plt.subplot(1,3,2)
plt.title("prediction heatmap of 110 slide (prob)")
prob_image1 = np.reshape(y_predict_prob_X_cep[45704:75254],(-1,197))
plt.imshow(test1)
plt.imshow(prob_image1 , cmap='jet',alpha=0.5)

# prediction of label heatmap of 110 slide
plt.subplot(1,3,3)
plt.title("prediction heatmap of 110 slide (label)")
label_image1 = np.reshape(y_predict_label_Xcep[45704:75254],(-1,197))
plt.imshow(test1)
plt.imshow(label_image1 , cmap='jet',alpha=0.5)

# %%
# Ground Truth of 005 slide
plt.figure(figsize=(21,21), dpi=100)
plt.subplot(1,3,1)
plt.title("Ground Truth of 005 slide")
plt.imshow(slide_test_image3)
plt.imshow(tumor_mask_test_image3, cmap='jet', alpha=0.5)

# prediction of probability heatmap of 005 slide
plt.subplot(1,3,2)
plt.title("prediction heatmap of 005 slide (prob)")
prob_image3 = np.reshape(y_predict_prob_X_cep[75254:],(-1,204))
plt.imshow(test3)
plt.imshow(prob_image3 , cmap='jet',alpha=0.5)

# prediction of label heatmap of 005 slide
plt.subplot(1,3,3)
plt.title("prediction heatmap of 005 slide (label)")
label_image3 = np.reshape(y_predict_label_Xcep[75254:],(-1,204))
plt.imshow(test3)
plt.imshow(label_image3 , cmap='jet',alpha=0.5)

# %%
model_Xcep.save_weights('/home/wenshen2543/model/model_Xcep_weights.h5')
model_Xcep.save('/home/wenshen2543/model/model_Xcep.h5')
# Out:
# /home/wenshen2543/anaconda3/lib/python3.5/site-packages/keras/models.py:61: UserWarning: TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file.You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
#   'TensorFlow optimizers do not '
